# %%
# conda install -c conda-forge imbalanced-learn
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# pip install graphvizד
# Out:
# Requirement already satisfied: graphviz in c:\users\matane\anaconda3\lib\site-packages (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# pip install -U imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\matane\anaconda3\lib\site-packages (0.9.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\matane\anaconda3\lib\site-packages (from imbalanced-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\matane\anaconda3\lib\site-packages (from imbalanced-learn) (2.2.0)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\matane\anaconda3\lib\site-packages (from imbalanced-learn) (1.21.5)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\matane\anaconda3\lib\site-packages (from imbalanced-learn) (1.7.3)
# Requirement already satisfied: scikit-learn>=1.0.1 in c:\users\matane\anaconda3\lib\site-packages (from imbalanced-learn) (1.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# pip install imblearn
# Out:
# Requirement already satisfied: imblearn in c:\users\matane\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\matane\anaconda3\lib\site-packages (from imblearn) (0.9.0)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\matane\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.21.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\matane\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (2.2.0)
# Requirement already satisfied: scikit-learn>=1.0.1 in c:\users\matane\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\matane\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\matane\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.7.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# pip install pydotplus
# Out:
# Requirement already satisfied: pydotplus in c:\users\matane\anaconda3\lib\site-packages (2.0.2)
# Requirement already satisfied: pyparsing>=2.0.1 in c:\users\matane\anaconda3\lib\site-packages (from pydotplus) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.tree import DecisionTreeClassifier, export_graphviz

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
import time
import datetime


# import for Decision Tree
from sklearn.tree import DecisionTreeClassifier 

# import for Random forest
from sklearn.ensemble import RandomForestClassifier

# import for KNN
from sklearn.neighbors import KNeighborsClassifier

from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold

from sklearn.model_selection import train_test_split 
from sklearn import metrics  
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import KFold
from sklearn import svm
from sklearn.ensemble import BaggingClassifier
from sklearn.svm import SVC

from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from scipy import stats 

from sklearn.tree import export_graphviz
from IPython.display import Image  
import pydotplus
import os
from pprint import pprint

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA as pca
from imblearn.over_sampling import SMOTE
# import imblearn
from imblearn.over_sampling import ADASYN
from imblearn.over_sampling import SMOTE 
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline

# %%
# Class for printing with underline, colors and bold
class bcolors:
    HEADER = '\033[95m'
    OKCYAN = '\033[96m'
    ENDC = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'

# %%
# for inline plots in jupyter
# %matplotlib inline

# %%
sns.set(color_codes=True) # settings for seaborn plotting style
sns.set(rc={'figure.figsize':(5,5)}) # settings for seaborn plot sizes

# %% [markdown]
# # now begin to work - use the new csv

# %%
df = pd.read_csv("train_ready.csv")

# %%
X = df.drop('Response', axis=1)
y = df['Response']

# %%
print(type(X))
X_temp=X.copy(deep=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# X = X.to_numpy()

# %%
print(type(X))
print(type(X_temp))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# #### Acuuracy and confusion matrix:

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %% [markdown]
# # <font color = 'red'> Decision Tree </font>

# %% [markdown]
# ### Find the hyperparameters

# %%
#### Randomized Search

# %%
dt = DecisionTreeClassifier(splitter='best',random_state=42)

print('Parameters currently in use:\n')
pprint(dt.get_params())
# Out:
# Parameters currently in use:
#
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': 42,
#  'splitter': 'best'}

# %% [markdown]
# Parameters currently in use:
#
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': 42,
#  'splitter': 'best'}

# %%
criterion= ['gini','entropy']

max_depth = [k for k in range(2,50)]

min_samples_split = [2,3,4,10,50,100,150,200,250,300,350,400]

min_samples_leaf = [2,3,4,10,50,100,150,200,250,300,350,400]

random_grid = {
               'criterion': criterion, 
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               }

# %% [markdown]
# #### Randomized Search

# %%
dt_random = RandomizedSearchCV(estimator = dt, param_distributions = random_grid, n_iter = 100,cv = 10,
                               verbose = 2, random_state = 42, n_jobs = -1)
dt_random.fit(X_train, y_train)
parameters = dt_random.best_params_
# Out:
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits

# %%
parameters = dt_random.best_params_
parameters
# Out:
# {'min_samples_split': 3,
#  'min_samples_leaf': 4,
#  'max_depth': 6,
#  'criterion': 'entropy'}

# %% [markdown]
# {'min_samples_split': 3,
#  'min_samples_leaf': 4,
#  'max_depth': 6,
#  'criterion': 'entropy'}

# %% [markdown]
# ## CHEACK IMPROVEMVET (SANITY) for random

# %%
dt.fit(X_train, y_train)
dt_y_pred = dt.predict(X_test)
dt_accuracy = metrics.accuracy_score(y_test, dt_y_pred)
print('base model accuracy = {:0.2f}%'.format(dt_accuracy*100))

best_random = dt_random.best_estimator_
random_y_pred = best_random.predict(X_test)
random_accuracy = metrics.accuracy_score(y_test, random_y_pred)
print('random model accuracy = {:0.2f}%'.format(random_accuracy*100))

print('Improvement of {:0.2f}%.'.format( 100 * (random_accuracy - dt_accuracy) / dt_accuracy))
# Out:
# base model accuracy = 82.14%
# random model accuracy = 85.95%
# Improvement of 4.64%.

# %%
criterion = [parameters['criterion']]
criterion
# Out:
# ['entropy']

# %%
# arrange parameters for grid from values close to the random search 
parameters
# Out:
# {'min_samples_split': 3,
#  'min_samples_leaf': 4,
#  'max_depth': 6,
#  'criterion': 'entropy'}

# %%
param_grid = {'min_samples_split': [2, 5],
         'min_samples_leaf': [3, 6],
         'max_depth': [4, 7],
         'criterion': ['entropy','gini']}

grid_search = GridSearchCV(estimator = dt, param_grid = param_grid, cv = 5, n_jobs = -1, verbose=2)

# %%
grid_search.fit(X_train, y_train)
parameters_dt = grid_search.best_params_
parameters_dt
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# {'criterion': 'entropy',
#  'max_depth': 4,
#  'min_samples_leaf': 6,
#  'min_samples_split': 2}

# %%
parameters_dt = {'criterion': 'entropy',
                'max_depth': 4,
                 'min_samples_leaf': 6,
                 'min_samples_split': 2}

# %%
dt = DecisionTreeClassifier(criterion='entropy', splitter='best', 
                          max_depth=4, min_samples_split=8,
                            min_samples_leaf=2, random_state=42)
dt.fit(X_train, y_train)
print(dt)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4, min_samples_leaf=2,
#                        min_samples_split=8, random_state=42)

# %% [markdown]
# ## CHEACK IMPROVEMVET (SANITY) after grid

# %%
best_grid = grid_search.best_estimator_
best_grid.fit(X_train, y_train)
grid_y_pred = best_grid.predict(X_test)
grid_accuracy = metrics.accuracy_score(y_test, grid_y_pred)
print('base model accuracy = {:0.2f}%'.format(dt_accuracy*100))
print('grid model accuracy = {:0.2f}%'.format(grid_accuracy*100))
print('random model accuracy = {:0.2f}%'.format(random_accuracy*100))

print('Improvement of {:0.2f}%.'.format( 100 * (grid_accuracy - dt_accuracy) / dt_accuracy))

# print('Improvement of {:0.2f}%.'.format( 100 * (grid_accuracy - random_accuracy) / random_accuracy))

# print('Improvement of {:0.2f}%.'.format( 100 * (random_accuracy - grid_accuracy) / grid_accuracy))
# Out:
# base model accuracy = 82.14%
# grid model accuracy = 85.48%
# random model accuracy = 85.95%
# Improvement of 4.06%.
# Improvement of -0.55%.
# Improvement of 0.56%.

# %%
# TODO אולי לחזור לשים את הפרמרטים של הרנדום לעומת הגריד ולבדוק איך יצא פחות טוב הגריד

# %% [markdown]
# ### Visualization
#
# #### Printing Decision Tree

# %%
dot = export_graphviz(dt, filled=True, rounded=True, 
                    special_characters=True,feature_names = X.columns,class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot)
graph.write_png('DT_Tree.png')
Image(graph.create_png())

# %% [markdown]
# #### Check Accuracy VS max_depth--??

# %%
# grid_search.best_score_
dt_random.cv_results_
# Out:
# {'mean_fit_time': array([0.02496755, 0.01153629, 0.02539458, 0.03530476, 0.01854942,
#         0.02294018, 0.01595604, 0.00817604, 0.00947402, 0.01157014,
#         0.00817866, 0.00909388, 0.00794556, 0.00886793, 0.00907962,
#         0.01269286, 0.00846632, 0.00785918, 0.01370232, 0.0114866 ,
#         0.00806901, 0.00765469, 0.00967522, 0.00786083, 0.0151278 ,
#         0.00947635, 0.01311328, 0.00907431, 0.01110113, 0.00927341,
#         0.00987773, 0.01009123, 0.01289744, 0.02001467, 0.01182594,
#         0.00886717, 0.01009412, 0.01289532, 0.01290796, 0.01181049,
#         0.01129529, 0.01015546, 0.00544362, 0.00877566, 0.01408103,
#         0.02097349, 0.00828764, 0.00898304, 0.01182747, 0.01981125,
#         0.01174657, 0.02102151, 0.0131135 , 0.00845053, 0.01227796,
#         0.00858948, 0.0161272 , 0.01553266, 0.01694281, 0.01087751,
#         0.0127135 , 0.01188638, 0.01752615, 0.01774511, 0.00747035,
#         0.01773982, 0.01267815, 0.01957078, 0.0110934 , 0.0139107 ,
#         0.00747447, 0.01331472, 0.00565908, 0.01876402, 0.00705187,
#         0.01268799, 0.01976635, 0.0116977 , 0.01352837, 0.01268301,
#         0.01673806, 0.00968704, 0.01915944, 0.02180552, 0.00927546,
#         0.01088588, 0.0149327 , 0.01531758, 0.00907772, 0.01372259,
#         0.00847414, 0.0080842 , 0.0082859 , 0.00748308, 0.01109006,
#         0.02037044, 0.01027944, 0.00808792, 0.02055364, 0.00907979]),
#  'std_fit_time': array([1.75847792e-02, 5.60853886e-03, 6.45041248e-03, 1.06289791e-02,
#         5.22582183e-03, 5.51536816e-03, 5.36908513e-03, 1.65510896e-03,
#         2.41225900e-03, 2.82693801e-03, 1.65721621e-03, 2.21717333e-03,
#         3.62236949e-03, 4.04210922e-03, 4.34088459e-03, 4.03448480e-03,
#         3.21990682e-03, 3.04247083e-03, 4.11830015e-03, 3.37296670e-03,
#         4.03454623e-03, 3.46512108e-03, 1.52809357e-03, 3.54374350e-03,
#         3.94059948e-03, 2.71602071e-03, 3.84407667e-03, 2.58878553e-03,
#         2.42004224e-03, 2.58039296e-03, 3.65411252e-03, 3.30026865e-05,
#         3.94826923e-03, 3.75323373e-03, 2.85127710e-03, 2.41786723e-03,
#         3.60250366e-03, 3.50499258e-03, 3.94563563e-03, 5.71026071e-03,
#         3.00979603e-03, 3.89443298e-03, 3.90735069e-03, 4.56045171e-03,
#         3.20031652e-03, 3.97316546e-03, 3.85537193e-03, 4.56054459e-03,
#         3.23059959e-03, 5.44837431e-03, 3.85282261e-03, 2.50709800e-03,
#         3.80109692e-03, 3.22541506e-03, 3.08387294e-03, 2.21386552e-03,
#         4.95001039e-03, 4.13151437e-03, 4.15252875e-03, 6.57428899e-03,
#         4.03003366e-03, 4.80003470e-03, 5.25462630e-03, 3.45728488e-03,
#         3.84317109e-03, 3.91698737e-03, 3.60351285e-03, 4.77317592e-03,
#         6.16852835e-03, 4.35782543e-03, 3.61825369e-03, 4.54250477e-03,
#         4.49500126e-03, 2.39705086e-03, 3.39198709e-03, 4.03372216e-03,
#         3.69438481e-03, 2.34862062e-03, 4.42627500e-03, 4.03649558e-03,
#         4.41986570e-03, 8.21726809e-04, 2.43317370e-03, 2.51818678e-03,
#         2.41623661e-03, 2.40990572e-03, 4.15610704e-03, 4.52211373e-03,
#         2.59663332e-03, 4.49179989e-03, 3.22633637e-03, 3.60872782e-03,
#         3.17047894e-03, 3.61396787e-03, 2.58452642e-03, 3.77304509e-03,
#         6.06615016e-04, 3.12302797e-03, 4.58747002e-03, 2.41854233e-03]),
#  'mean_score_time': array([0.00790825, 0.00442131, 0.005388  , 0.00508583, 0.00309141,
#         0.00498857, 0.00368714, 0.00289376, 0.00349162, 0.00428777,
#         0.00368938, 0.00279868, 0.00462396, 0.0036294 , 0.00442355,
#         0.00504749, 0.0034256 , 0.00343637, 0.00323122, 0.00343096,
#         0.00422416, 0.00343316, 0.00182076, 0.00323088, 0.00423169,
#         0.00201666, 0.0032249 , 0.00382655, 0.00322468, 0.00201972,
#         0.0034302 , 0.00261896, 0.00322971, 0.00492027, 0.00290864,
#         0.00121326, 0.00221946, 0.00403972, 0.00443139, 0.00302238,
#         0.00307162, 0.00239398, 0.00404029, 0.00408297, 0.00301096,
#         0.0032758 , 0.00253208, 0.00341468, 0.00333154, 0.00383921,
#         0.0028326 , 0.00203772, 0.00403204, 0.0024205 , 0.0037529 ,
#         0.0043246 , 0.0028219 , 0.0042285 , 0.00222018, 0.00584183,
#         0.00444162, 0.00161676, 0.0034456 , 0.00141118, 0.00242343,
#         0.00242639, 0.00344067, 0.00363598, 0.00322576, 0.00424612,
#         0.00463805, 0.00444143, 0.00543215, 0.00222607, 0.00322435,
#         0.0050426 , 0.00404465, 0.00302098, 0.00281534, 0.00324349,
#         0.00463226, 0.00201335, 0.00100715, 0.00242107, 0.00121412,
#         0.00323203, 0.0022217 , 0.00565772, 0.00303848, 0.00343668,
#         0.00282118, 0.00282209, 0.00564835, 0.00403595, 0.00383403,
#         0.00362408, 0.00565014, 0.00365295, 0.00283666, 0.0028147 ]),
#  'std_score_time': array([0.00786408, 0.00446011, 0.00127798, 0.00254181, 0.00069863,
#         0.00204484, 0.00099921, 0.00129748, 0.00142831, 0.00223147,
#         0.00134172, 0.00247405, 0.00449583, 0.0044911 , 0.00368099,
#         0.00394969, 0.00423365, 0.00360335, 0.0037392 , 0.00403614,
#         0.00426241, 0.00403766, 0.00291755, 0.00373201, 0.00363964,
#         0.00360406, 0.00372753, 0.00396512, 0.00414421, 0.0036128 ,
#         0.00403502, 0.0040356 , 0.0041536 , 0.00475274, 0.00295898,
#         0.00241973, 0.00354501, 0.00433241, 0.00368863, 0.00340615,
#         0.00347186, 0.0027224 , 0.00423299, 0.00321291, 0.00303703,
#         0.00297665, 0.0030994 , 0.00271224, 0.00256347, 0.00357681,
#         0.00384533, 0.00256156, 0.00395623, 0.00357896, 0.0035428 ,
#         0.00304845, 0.00434266, 0.00364725, 0.00354748, 0.00407146,
#         0.0043057 , 0.0029651 , 0.00359954, 0.00238587, 0.00347036,
#         0.0039162 , 0.00405426, 0.00450126, 0.00373012, 0.00446624,
#         0.00393587, 0.00449741, 0.00450624, 0.00306151, 0.00372563,
#         0.00395224, 0.00383395, 0.00424704, 0.00433253, 0.00375556,
#         0.00392846, 0.00310969, 0.00242332, 0.00390451, 0.0030252 ,
#         0.00373775, 0.00303605, 0.00431349, 0.00386131, 0.00404287,
#         0.00434231, 0.00350861, 0.00430508, 0.0045965 , 0.00397416,
#         0.00368795, 0.0046735 , 0.00431815, 0.00326605, 0.00393316]),
#  'param_min_samples_split': masked_array(data=[350, 250, 4, 4, 200, 2, 50, 350, 3, 350, 4, 350, 350,
#                     250, 400, 400, 150, 100, 3, 400, 10, 3, 300, 200, 400,
#                     2, 250, 200, 3, 300, 2, 10, 250, 4, 350, 4, 3, 200,
#                     400, 400, 4, 300, 350, 100, 4, 10, 150, 200, 50, 150,
#                     50, 4, 150, 50, 100, 200, 250, 200, 100, 300, 300, 2,
#                     3, 250, 300, 10, 200, 4, 200, 350, 250, 200, 4, 150,
#                     250, 200, 3, 200, 200, 3, 3, 3, 100, 3, 10, 300, 250,
#                     150, 300, 400, 100, 3, 300, 400, 400, 4, 400, 300, 4,
#                     400],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_samples_leaf': masked_array(data=[100, 400, 100, 4, 2, 3, 50, 300, 150, 4, 400, 250, 250,
#                     300, 350, 3, 300, 250, 50, 100, 350, 10, 350, 350, 2,
#                     200, 4, 200, 150, 100, 100, 150, 2, 4, 50, 300, 150, 4,
#                     2, 200, 100, 10, 400, 350, 50, 4, 250, 300, 200, 3,
#                     250, 2, 50, 400, 100, 300, 2, 10, 4, 150, 2, 150, 4, 3,
#                     350, 50, 10, 3, 10, 3, 200, 50, 300, 3, 350, 100, 2,
#                     50, 100, 50, 3, 400, 2, 4, 250, 100, 10, 4, 250, 50, 3,
#                     350, 200, 350, 400, 3, 100, 400, 10, 250],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[4, 7, 39, 47, 38, 37, 32, 41, 45, 5, 47, 32, 40, 34,
#                     32, 31, 11, 13, 7, 27, 49, 2, 18, 38, 37, 46, 10, 33,
#                     25, 39, 46, 44, 31, 14, 18, 19, 8, 16, 21, 17, 23, 3,
#                     20, 22, 34, 15, 7, 10, 12, 33, 26, 29, 15, 30, 39, 27,
#                     15, 27, 25, 12, 25, 30, 6, 20, 2, 20, 45, 40, 3, 21,
#                     28, 7, 38, 11, 23, 24, 13, 29, 6, 23, 9, 34, 29, 47,
#                     28, 9, 21, 44, 49, 41, 3, 31, 24, 8, 44, 34, 42, 6, 37,
#                     19],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_criterion': masked_array(data=['entropy', 'gini', 'gini', 'entropy', 'gini',
#                     'entropy', 'entropy', 'gini', 'gini', 'gini',
#                     'entropy', 'gini', 'gini', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'gini', 'gini', 'entropy',
#                     'entropy', 'entropy', 'gini', 'gini', 'gini', 'gini',
#                     'gini', 'gini', 'gini', 'entropy', 'gini', 'entropy',
#                     'entropy', 'entropy', 'entropy', 'gini', 'entropy',
#                     'gini', 'gini', 'entropy', 'entropy', 'gini', 'gini',
#                     'gini', 'gini', 'gini', 'entropy', 'gini', 'gini',
#                     'entropy', 'gini', 'gini', 'entropy', 'entropy',
#                     'gini', 'entropy', 'entropy', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'entropy', 'entropy', 'gini',
#                     'entropy', 'entropy', 'gini', 'gini', 'entropy',
#                     'entropy', 'entropy', 'gini', 'entropy', 'entropy',
#                     'gini', 'entropy', 'gini', 'gini', 'entropy', 'gini',
#                     'gini', 'entropy', 'entropy', 'entropy', 'gini',
#                     'entropy', 'entropy', 'entropy', 'gini', 'gini',
#                     'gini', 'gini', 'entropy', 'gini', 'entropy',
#                     'entropy', 'entropy', 'entropy', 'entropy', 'entropy'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'min_samples_split': 350,
#    'min_samples_leaf': 100,
#    'max_depth': 4,
#    'criterion': 'entropy'},
#   {'min_samples_split': 250,
#    'min_samples_leaf': 400,
#    'max_depth': 7,
#    'criterion': 'gini'},
#   {'min_samples_split': 4,
#    'min_samples_leaf': 100,
#    'max_depth': 39,
#    'criterion': 'gini'},
#   {'min_samples_split': 4,
#    'min_samples_leaf': 4,
#    'max_depth': 47,
#    'criterion': 'entropy'},
#   {'min_samples_split': 200,
#    'min_samples_leaf': 2,
#    'max_depth': 38,
#    'criterion': 'gini'},
#   {'min_samples_split': 2,
#    'min_samples_leaf': 3,
#    'max_depth': 37,
#    'criterion': 'entropy'},
#   {'min_samples_split': 50,
#    'min_samples_leaf': 50,
#    'max_depth': 32,
#    'criterion': 'entropy'},
#   {'min_samples_split': 350,
#    'min_samples_leaf': 300,
#    'max_depth': 41,
#    'criterion': 'gini'},
#   {'min_samples_split': 3,
#    'min_samples_leaf': 150,
#    'max_depth': 45,
#    'criterion': 'gini'},
#   {'min_samples_split': 350,
#    'min_samples_leaf': 4,
#    'max_depth': 5,
#    'criterion': 'gini'},
#   {'min_samples_split': 4,
#    'min_samples_leaf': 400,
#    'max_depth': 47,
#    'criterion': 'entropy'},
#   {'min_samples_split': 350,
#    'min_samples_leaf': 250,
#    'max_depth': 32,
#    'criterion': 'gini'},
#   {'min_samples_split': 350,
#    'min_samples_leaf': 250,
#    'max_depth': 40,
#    'criterion': 'gini'},
#   {'min_samples_split': 250,
#    'min_samples_leaf': 300,
#    'max_depth': 34,
#    'criterion': 'entropy'},
#   {'min_samples_split': 400,
#    'min_samples_leaf': 350,
#    'max_depth': 32,
#    'criterion': 'entropy'},
#   {'min_samples_split': 400,
#    'min_samples_leaf': 3,
#    'max_depth': 31,
#    'criterion': 'entropy'},
#   {'min_samples_split': 150,
#    'min_samples_leaf': 300,
#    'max_depth': 11,
#    'criterion': 'entropy'},
#   {'min_samples_split': 100,
#    'min_samples_leaf': 250,
#    'max_depth': 13,
#    'criterion': 'gini'},
#   {'min_samples_split': 3,
#    'min_samples_leaf': 50,
#    'max_depth': 7,
#    'criterion': 'gini'},
#   {'min_samples_split': 400,
#    'min_samples_leaf': 100,
#    'max_depth': 27,
#    'criterion': 'entropy'},
#   {'min_samples_split': 10,
#    'min_samples_leaf': 350,
#    'max_depth': 49,
#    'criterion': 'entropy'},
#   {'min_samples_split': 3,
#    'min_samples_leaf': 10,
#    'max_depth': 2,
#    'criterion': 'entropy'},
#   {'min_samples_split': 300,
#    'min_samples_leaf': 350,
#    'max_depth': 18,
#    'criterion': 'gini'},
#   {'min_samples_split': 200,
#    'min_samples_leaf': 350,
#    'max_depth': 38,
#    'criterion': 'gini'},
#   {'min_samples_split': 400,
#    'min_samples_leaf': 2,
#    'max_depth': 37,
#    'criterion': 'gini'},
#   {'min_samples_split': 2,
#    'min_samples_leaf': 200,
#    'max_depth': 46,
#    'criterion': 'gini'},
#   {'min_samples_split': 250,
#    'min_samples_leaf': 4,
#    'max_depth': 10,
#    'criterion': 'gini'},
#   {'min_samples_split': 200,
#    'min_samples_leaf': 200,
#    'max_depth': 33,
#    'criterion': 'gini'},
#   {'min_samples_split': 3,
#    'min_samples_leaf': 150,
#    'max_depth': 25,
#    'criterion': 'gini'},
#   {'min_samples_split': 300,
#    'min_samples_leaf': 100,
#    'max_depth': 39,
#    'criterion': 'entropy'},
#   {'min_samples_split': 2,
#    'min_samples_leaf': 100,
#    'max_depth': 46,
#    'criterion': 'gini'},
#   {'min_samples_split': 10,
#    'min_samples_leaf': 150,
#    'max_depth': 44,
#    'criterion': 'entropy'},
#   {'min_samples_split': 250,
#    'min_samples_leaf': 2,
#    'max_depth': 31,
#    'criterion': 'entropy'},
#   {'min_samples_split': 4,
#    'min_samples_leaf': 4,
#    'max_depth': 14,
#    'criterion': 'entropy'},
#   {'min_samples_split': 350,
#    'min_samples_leaf': 50,
#    'max_depth': 18,
#    'criterion': 'entropy'},
#   {'min_samples_split': 4,
#    'min_samples_leaf': 300,
#    'max_depth': 19,
#    'criterion': 'gini'},
#   {'min_samples_split': 3,
#    'min_samples_leaf': 150,
#    'max_depth': 8,
#    'criterion': 'entropy'},
#   {'min_samples_split': 200,
#    'min_samples_leaf': 4,
#    'max_depth': 16,
#    'criterion': 'gini'},
#   {'min_samples_split': 400,
#    'min_samples_leaf': 2,
#    'max_depth': 21,
#    'criterion': 'gini'},
#   {'min_samples_split': 400,
#    'min_samples_leaf': 200,
#    'max_depth': 17,
#    'criterion': 'entropy'},
#   {'min_samples_split': 4,
#    'min_samples_leaf': 100,
#    'max_depth': 23,
#    'criterion': 'entropy'},
#   {'min_samples_split': 300,
#    'min_samples_leaf': 10,
#    'max_depth': 3,
#    'criterion': 'gini'},
#   {'min_samples_split': 350,
#    'min_samples_leaf': 400,
#    'max_depth': 20,
#    'criterion': 'gini'},
#   {'min_samples_split': 100,
#    'min_samples_leaf': 350,
#    'max_depth': 22,
#    'criterion': 'gini'},
#   {'min_samples_split': 4,
#    'min_samples_leaf': 50,
#    'max_depth': 34,
#    'criterion': 'gini'},
#   {'min_samples_split': 10,
#    'min_samples_leaf': 4,
#    'max_depth': 15,
#    'criterion': 'gini'},
#   {'min_samples_split': 150,
#    'min_samples_leaf': 250,
#    'max_depth': 7,
#    'criterion': 'entropy'},
#   {'min_samples_split': 200,
#    'min_samples_leaf': 300,
#    'max_depth': 10,
#    'criterion': 'gini'},
#   {'min_samples_split': 50,
#    'min_samples_leaf': 200,
#    'max_depth': 12,
#    'criterion': 'gini'},
#   {'min_samples_split': 150,
#    'min_samples_leaf': 3,
#    'max_depth': 33,
#    'criterion': 'entropy'},
#   {'min_samples_split': 50,
#    'min_samples_leaf': 250,
#    'max_depth': 26,
#    'criterion': 'gini'},
#   {'min_samples_split': 4,
#    'min_samples_leaf': 2,
#    'max_depth': 29,
#    'criterion': 'gini'},
#   {'min_samples_split': 150,
#    'min_samples_leaf': 50,
#    'max_depth': 15,
#    'criterion': 'entropy'},
#   {'min_samples_split': 50,
#    'min_samples_leaf': 400,
#    'max_depth': 30,
#    'criterion': 'entropy'},
#   {'min_samples_split': 100,
#    'min_samples_leaf': 100,
#    'max_depth': 39,
#    'criterion': 'gini'},
#   {'min_samples_split': 200,
#    'min_samples_leaf': 300,
#    'max_depth': 27,
#    'criterion': 'entropy'},
#   {'min_samples_split': 250,
#    'min_samples_leaf': 2,
#    'max_depth': 15,
#    'criterion': 'entropy'},
#   {'min_samples_split': 200,
#    'min_samples_leaf': 10,
#    'max_depth': 27,
#    'criterion': 'entropy'},
#   {'min_samples_split': 100,
#    'min_samples_leaf': 4,
#    'max_depth': 25,
#    'criterion': 'entropy'},
#   {'min_samples_split': 300,
#    'min_samples_leaf': 150,
#    'max_depth': 12,
#    'criterion': 'entropy'},
#   {'min_samples_split': 300,
#    'min_samples_leaf': 2,
#    'max_depth': 25,
#    'criterion': 'entropy'},
#   {'min_samples_split': 2,
#    'min_samples_leaf': 150,
#    'max_depth': 30,
#    'criterion': 'entropy'},
#   {'min_samples_split': 3,
#    'min_samples_leaf': 4,
#    'max_depth': 6,
#    'criterion': 'entropy'},
#   {'min_samples_split': 250,
#    'min_samples_leaf': 3,
#    'max_depth': 20,
#    'criterion': 'gini'},
#   {'min_samples_split': 300,
#    'min_samples_leaf': 350,
#    'max_depth': 2,
#    'criterion': 'entropy'},
#   {'min_samples_split': 10,
#    'min_samples_leaf': 50,
#    'max_depth': 20,
#    'criterion': 'entropy'},
#   {'min_samples_split': 200,
#    'min_samples_leaf': 10,
#    'max_depth': 45,
#    'criterion': 'gini'},
#   {'min_samples_split': 4,
#    'min_samples_leaf': 3,
#    'max_depth': 40,
#    'criterion': 'gini'},
#   {'min_samples_split': 200,
#    'min_samples_leaf': 10,
#    'max_depth': 3,
#    'criterion': 'entropy'},
#   {'min_samples_split': 350,
#    'min_samples_leaf': 3,
#    'max_depth': 21,
#    'criterion': 'entropy'},
#   {'min_samples_split': 250,
#    'min_samples_leaf': 200,
#    'max_depth': 28,
#    'criterion': 'entropy'},
#   {'min_samples_split': 200,
#    'min_samples_leaf': 50,
#    'max_depth': 7,
#    'criterion': 'gini'},
#   {'min_samples_split': 4,
#    'min_samples_leaf': 300,
#    'max_depth': 38,
#    'criterion': 'entropy'},
#   {'min_samples_split': 150,
#    'min_samples_leaf': 3,
#    'max_depth': 11,
#    'criterion': 'entropy'},
#   {'min_samples_split': 250,
#    'min_samples_leaf': 350,
#    'max_depth': 23,
#    'criterion': 'gini'},
#   {'min_samples_split': 200,
#    'min_samples_leaf': 100,
#    'max_depth': 24,
#    'criterion': 'entropy'},
#   {'min_samples_split': 3,
#    'min_samples_leaf': 2,
#    'max_depth': 13,
#    'criterion': 'gini'},
#   {'min_samples_split': 200,
#    'min_samples_leaf': 50,
#    'max_depth': 29,
#    'criterion': 'gini'},
#   {'min_samples_split': 200,
#    'min_samples_leaf': 100,
#    'max_depth': 6,
#    'criterion': 'entropy'},
#   {'min_samples_split': 3,
#    'min_samples_leaf': 50,
#    'max_depth': 23,
#    'criterion': 'gini'},
#   {'min_samples_split': 3,
#    'min_samples_leaf': 3,
#    'max_depth': 9,
#    'criterion': 'gini'},
#   {'min_samples_split': 3,
#    'min_samples_leaf': 400,
#    'max_depth': 34,
#    'criterion': 'entropy'},
#   {'min_samples_split': 100,
#    'min_samples_leaf': 2,
#    'max_depth': 29,
#    'criterion': 'entropy'},
#   {'min_samples_split': 3,
#    'min_samples_leaf': 4,
#    'max_depth': 47,
#    'criterion': 'entropy'},
#   {'min_samples_split': 10,
#    'min_samples_leaf': 250,
#    'max_depth': 28,
#    'criterion': 'gini'},
#   {'min_samples_split': 300,
#    'min_samples_leaf': 100,
#    'max_depth': 9,
#    'criterion': 'entropy'},
#   {'min_samples_split': 250,
#    'min_samples_leaf': 10,
#    'max_depth': 21,
#    'criterion': 'entropy'},
#   {'min_samples_split': 150,
#    'min_samples_leaf': 4,
#    'max_depth': 44,
#    'criterion': 'entropy'},
#   {'min_samples_split': 300,
#    'min_samples_leaf': 250,
#    'max_depth': 49,
#    'criterion': 'gini'},
#   {'min_samples_split': 400,
#    'min_samples_leaf': 50,
#    'max_depth': 41,
#    'criterion': 'gini'},
#   {'min_samples_split': 100,
#    'min_samples_leaf': 3,
#    'max_depth': 3,
#    'criterion': 'gini'},
#   {'min_samples_split': 3,
#    'min_samples_leaf': 350,
#    'max_depth': 31,
#    'criterion': 'gini'},
#   {'min_samples_split': 300,
#    'min_samples_leaf': 200,
#    'max_depth': 24,
#    'criterion': 'entropy'},
#   {'min_samples_split': 400,
#    'min_samples_leaf': 350,
#    'max_depth': 8,
#    'criterion': 'gini'},
#   {'min_samples_split': 400,
#    'min_samples_leaf': 400,
#    'max_depth': 44,
#    'criterion': 'entropy'},
#   {'min_samples_split': 4,
#    'min_samples_leaf': 3,
#    'max_depth': 34,
#    'criterion': 'entropy'},
#   {'min_samples_split': 400,
#    'min_samples_leaf': 100,
#    'max_depth': 42,
#    'criterion': 'entropy'},
#   {'min_samples_split': 300,
#    'min_samples_leaf': 400,
#    'max_depth': 6,
#    'criterion': 'entropy'},
#   {'min_samples_split': 4,
#    'min_samples_leaf': 10,
#    'max_depth': 37,
#    'criterion': 'entropy'},
#   {'min_samples_split': 400,
#    'min_samples_leaf': 250,
#    'max_depth': 19,
#    'criterion': 'entropy'}],
#  'split0_test_score': array([0.86507937, 0.86507937, 0.86507937, 0.84126984, 0.88888889,
#         0.84126984, 0.88888889, 0.86507937, 0.86507937, 0.88888889,
#         0.86507937, 0.86507937, 0.86507937, 0.86507937, 0.86507937,
#         0.88888889, 0.86507937, 0.86507937, 0.88888889, 0.86507937,
#         0.86507937, 0.88095238, 0.86507937, 0.86507937, 0.88888889,
#         0.86507937, 0.88888889, 0.86507937, 0.86507937, 0.86507937,
#         0.86507937, 0.86507937, 0.88888889, 0.81746032, 0.88888889,
#         0.86507937, 0.86507937, 0.88888889, 0.88888889, 0.86507937,
#         0.86507937, 0.88888889, 0.86507937, 0.86507937, 0.88888889,
#         0.83333333, 0.86507937, 0.86507937, 0.86507937, 0.88888889,
#         0.86507937, 0.85714286, 0.88888889, 0.86507937, 0.86507937,
#         0.86507937, 0.88888889, 0.88888889, 0.92063492, 0.86507937,
#         0.88888889, 0.86507937, 0.9047619 , 0.88888889, 0.86507937,
#         0.88888889, 0.88888889, 0.85714286, 0.88888889, 0.88888889,
#         0.86507937, 0.88888889, 0.86507937, 0.88888889, 0.86507937,
#         0.86507937, 0.87301587, 0.88888889, 0.86507937, 0.88888889,
#         0.85714286, 0.86507937, 0.92063492, 0.84126984, 0.86507937,
#         0.86507937, 0.88888889, 0.88888889, 0.86507937, 0.88888889,
#         0.88888889, 0.86507937, 0.86507937, 0.86507937, 0.86507937,
#         0.84126984, 0.86507937, 0.86507937, 0.88095238, 0.86507937]),
#  'split1_test_score': array([0.85714286, 0.85714286, 0.85714286, 0.82539683, 0.84920635,
#         0.8015873 , 0.84920635, 0.85714286, 0.85714286, 0.84920635,
#         0.85714286, 0.85714286, 0.85714286, 0.85714286, 0.85714286,
#         0.83333333, 0.85714286, 0.85714286, 0.84920635, 0.85714286,
#         0.85714286, 0.86507937, 0.85714286, 0.85714286, 0.84920635,
#         0.85714286, 0.84920635, 0.85714286, 0.85714286, 0.85714286,
#         0.85714286, 0.85714286, 0.83333333, 0.83333333, 0.84920635,
#         0.85714286, 0.85714286, 0.84920635, 0.84920635, 0.85714286,
#         0.85714286, 0.84920635, 0.85714286, 0.85714286, 0.84920635,
#         0.85714286, 0.85714286, 0.85714286, 0.85714286, 0.80952381,
#         0.85714286, 0.84920635, 0.84920635, 0.85714286, 0.85714286,
#         0.85714286, 0.83333333, 0.80952381, 0.80952381, 0.85714286,
#         0.83333333, 0.85714286, 0.83333333, 0.84920635, 0.85714286,
#         0.84920635, 0.84920635, 0.84126984, 0.80952381, 0.83333333,
#         0.85714286, 0.84920635, 0.85714286, 0.80952381, 0.85714286,
#         0.85714286, 0.84920635, 0.84920635, 0.85714286, 0.84920635,
#         0.86507937, 0.85714286, 0.80952381, 0.82539683, 0.85714286,
#         0.85714286, 0.83333333, 0.80952381, 0.85714286, 0.84920635,
#         0.84920635, 0.85714286, 0.85714286, 0.85714286, 0.85714286,
#         0.8015873 , 0.85714286, 0.85714286, 0.80952381, 0.85714286]),
#  'split2_test_score': array([0.85714286, 0.85714286, 0.85714286, 0.83333333, 0.84126984,
#         0.83333333, 0.84920635, 0.85714286, 0.85714286, 0.84920635,
#         0.85714286, 0.85714286, 0.85714286, 0.85714286, 0.85714286,
#         0.84920635, 0.85714286, 0.85714286, 0.84920635, 0.85714286,
#         0.85714286, 0.83333333, 0.85714286, 0.85714286, 0.84126984,
#         0.85714286, 0.84920635, 0.85714286, 0.85714286, 0.85714286,
#         0.85714286, 0.85714286, 0.85714286, 0.83333333, 0.84920635,
#         0.85714286, 0.85714286, 0.84920635, 0.84126984, 0.85714286,
#         0.85714286, 0.84920635, 0.85714286, 0.85714286, 0.84920635,
#         0.83333333, 0.85714286, 0.85714286, 0.85714286, 0.85714286,
#         0.85714286, 0.84920635, 0.84920635, 0.85714286, 0.85714286,
#         0.85714286, 0.85714286, 0.85714286, 0.85714286, 0.85714286,
#         0.85714286, 0.85714286, 0.87301587, 0.84920635, 0.85714286,
#         0.84920635, 0.84920635, 0.84126984, 0.84920635, 0.84920635,
#         0.85714286, 0.84920635, 0.85714286, 0.85714286, 0.85714286,
#         0.85714286, 0.80952381, 0.84920635, 0.85714286, 0.84920635,
#         0.82539683, 0.85714286, 0.85714286, 0.83333333, 0.85714286,
#         0.85714286, 0.85714286, 0.85714286, 0.85714286, 0.84920635,
#         0.84920635, 0.85714286, 0.85714286, 0.85714286, 0.85714286,
#         0.83333333, 0.85714286, 0.85714286, 0.82539683, 0.85714286]),
#  'split3_test_score': array([0.85714286, 0.85714286, 0.85714286, 0.85714286, 0.88095238,
#         0.83333333, 0.88095238, 0.85714286, 0.85714286, 0.88095238,
#         0.85714286, 0.85714286, 0.85714286, 0.85714286, 0.85714286,
#         0.88095238, 0.85714286, 0.85714286, 0.88095238, 0.85714286,
#         0.85714286, 0.88095238, 0.85714286, 0.85714286, 0.88095238,
#         0.85714286, 0.88095238, 0.85714286, 0.85714286, 0.85714286,
#         0.85714286, 0.85714286, 0.87301587, 0.85714286, 0.88095238,
#         0.85714286, 0.85714286, 0.88095238, 0.88095238, 0.85714286,
#         0.85714286, 0.88095238, 0.85714286, 0.85714286, 0.88095238,
#         0.85714286, 0.85714286, 0.85714286, 0.85714286, 0.87301587,
#         0.85714286, 0.83333333, 0.88095238, 0.85714286, 0.85714286,
#         0.85714286, 0.87301587, 0.87301587, 0.84920635, 0.85714286,
#         0.87301587, 0.85714286, 0.8968254 , 0.88095238, 0.85714286,
#         0.88095238, 0.88095238, 0.86507937, 0.88095238, 0.88095238,
#         0.85714286, 0.88095238, 0.85714286, 0.87301587, 0.85714286,
#         0.85714286, 0.84920635, 0.88095238, 0.85714286, 0.88095238,
#         0.86507937, 0.85714286, 0.84920635, 0.85714286, 0.85714286,
#         0.85714286, 0.87301587, 0.87301587, 0.85714286, 0.88095238,
#         0.88095238, 0.85714286, 0.85714286, 0.85714286, 0.85714286,
#         0.83333333, 0.85714286, 0.85714286, 0.84920635, 0.85714286]),
#  'split4_test_score': array([0.85714286, 0.85714286, 0.85714286, 0.80952381, 0.8968254 ,
#         0.80952381, 0.88095238, 0.85714286, 0.85714286, 0.88095238,
#         0.85714286, 0.85714286, 0.85714286, 0.85714286, 0.85714286,
#         0.88095238, 0.85714286, 0.85714286, 0.88095238, 0.85714286,
#         0.85714286, 0.88095238, 0.85714286, 0.85714286, 0.88095238,
#         0.85714286, 0.88095238, 0.85714286, 0.85714286, 0.85714286,
#         0.85714286, 0.85714286, 0.86507937, 0.80952381, 0.88095238,
#         0.85714286, 0.85714286, 0.8968254 , 0.88095238, 0.85714286,
#         0.85714286, 0.88095238, 0.85714286, 0.85714286, 0.88095238,
#         0.81746032, 0.85714286, 0.85714286, 0.85714286, 0.86507937,
#         0.85714286, 0.82539683, 0.88095238, 0.85714286, 0.85714286,
#         0.85714286, 0.86507937, 0.86507937, 0.86507937, 0.85714286,
#         0.87301587, 0.85714286, 0.85714286, 0.88095238, 0.85714286,
#         0.88095238, 0.8968254 , 0.82539683, 0.88095238, 0.87301587,
#         0.85714286, 0.88095238, 0.85714286, 0.86507937, 0.85714286,
#         0.85714286, 0.84920635, 0.88095238, 0.85714286, 0.88095238,
#         0.84920635, 0.85714286, 0.86507937, 0.80952381, 0.85714286,
#         0.85714286, 0.86507937, 0.86507937, 0.85714286, 0.88095238,
#         0.8968254 , 0.85714286, 0.85714286, 0.85714286, 0.85714286,
#         0.80952381, 0.85714286, 0.85714286, 0.80952381, 0.85714286]),
#  'split5_test_score': array([0.85714286, 0.85714286, 0.85714286, 0.81746032, 0.87301587,
#         0.84920635, 0.87301587, 0.85714286, 0.85714286, 0.87301587,
#         0.85714286, 0.85714286, 0.85714286, 0.85714286, 0.85714286,
#         0.87301587, 0.85714286, 0.85714286, 0.87301587, 0.85714286,
#         0.85714286, 0.87301587, 0.85714286, 0.85714286, 0.87301587,
#         0.85714286, 0.87301587, 0.85714286, 0.85714286, 0.85714286,
#         0.85714286, 0.85714286, 0.87301587, 0.81746032, 0.87301587,
#         0.85714286, 0.85714286, 0.87301587, 0.87301587, 0.85714286,
#         0.85714286, 0.87301587, 0.85714286, 0.85714286, 0.87301587,
#         0.83333333, 0.85714286, 0.85714286, 0.85714286, 0.87301587,
#         0.85714286, 0.84920635, 0.87301587, 0.85714286, 0.85714286,
#         0.85714286, 0.87301587, 0.87301587, 0.87301587, 0.85714286,
#         0.87301587, 0.85714286, 0.88888889, 0.87301587, 0.85714286,
#         0.87301587, 0.87301587, 0.84126984, 0.87301587, 0.87301587,
#         0.85714286, 0.87301587, 0.85714286, 0.87301587, 0.85714286,
#         0.85714286, 0.85714286, 0.87301587, 0.85714286, 0.87301587,
#         0.84126984, 0.85714286, 0.87301587, 0.81746032, 0.85714286,
#         0.85714286, 0.87301587, 0.87301587, 0.85714286, 0.87301587,
#         0.87301587, 0.85714286, 0.85714286, 0.85714286, 0.85714286,
#         0.84920635, 0.85714286, 0.85714286, 0.85714286, 0.85714286]),
#  'split6_test_score': array([0.85714286, 0.85714286, 0.85714286, 0.80952381, 0.84126984,
#         0.82539683, 0.84920635, 0.85714286, 0.85714286, 0.84126984,
#         0.85714286, 0.85714286, 0.85714286, 0.85714286, 0.85714286,
#         0.85714286, 0.85714286, 0.85714286, 0.84920635, 0.85714286,
#         0.85714286, 0.86507937, 0.85714286, 0.85714286, 0.84126984,
#         0.85714286, 0.84126984, 0.85714286, 0.85714286, 0.85714286,
#         0.85714286, 0.85714286, 0.85714286, 0.80952381, 0.85714286,
#         0.85714286, 0.85714286, 0.84126984, 0.84126984, 0.85714286,
#         0.85714286, 0.84126984, 0.85714286, 0.85714286, 0.84920635,
#         0.84126984, 0.85714286, 0.85714286, 0.85714286, 0.85714286,
#         0.85714286, 0.82539683, 0.85714286, 0.85714286, 0.85714286,
#         0.85714286, 0.85714286, 0.85714286, 0.85714286, 0.85714286,
#         0.85714286, 0.85714286, 0.85714286, 0.84126984, 0.85714286,
#         0.84920635, 0.84126984, 0.82539683, 0.85714286, 0.85714286,
#         0.85714286, 0.85714286, 0.85714286, 0.85714286, 0.85714286,
#         0.85714286, 0.82539683, 0.85714286, 0.85714286, 0.84920635,
#         0.84920635, 0.85714286, 0.85714286, 0.80952381, 0.85714286,
#         0.85714286, 0.85714286, 0.85714286, 0.85714286, 0.85714286,
#         0.84126984, 0.85714286, 0.85714286, 0.85714286, 0.85714286,
#         0.82539683, 0.85714286, 0.85714286, 0.80952381, 0.85714286]),
#  'split7_test_score': array([0.85714286, 0.85714286, 0.85714286, 0.85714286, 0.86507937,
#         0.84920635, 0.86507937, 0.85714286, 0.85714286, 0.86507937,
#         0.85714286, 0.85714286, 0.85714286, 0.85714286, 0.85714286,
#         0.86507937, 0.85714286, 0.85714286, 0.86507937, 0.85714286,
#         0.85714286, 0.88095238, 0.85714286, 0.85714286, 0.86507937,
#         0.85714286, 0.86507937, 0.85714286, 0.85714286, 0.85714286,
#         0.85714286, 0.85714286, 0.88095238, 0.85714286, 0.86507937,
#         0.85714286, 0.85714286, 0.86507937, 0.86507937, 0.85714286,
#         0.85714286, 0.86507937, 0.85714286, 0.85714286, 0.86507937,
#         0.88095238, 0.85714286, 0.85714286, 0.85714286, 0.88095238,
#         0.85714286, 0.9047619 , 0.86507937, 0.85714286, 0.85714286,
#         0.85714286, 0.88095238, 0.88095238, 0.88095238, 0.85714286,
#         0.88095238, 0.85714286, 0.8968254 , 0.86507937, 0.85714286,
#         0.86507937, 0.86507937, 0.9047619 , 0.86507937, 0.86507937,
#         0.85714286, 0.86507937, 0.85714286, 0.88095238, 0.85714286,
#         0.85714286, 0.8968254 , 0.86507937, 0.85714286, 0.86507937,
#         0.87301587, 0.85714286, 0.88095238, 0.85714286, 0.85714286,
#         0.85714286, 0.88095238, 0.88095238, 0.85714286, 0.86507937,
#         0.86507937, 0.85714286, 0.85714286, 0.85714286, 0.85714286,
#         0.84920635, 0.85714286, 0.85714286, 0.85714286, 0.85714286]),
#  'split8_test_score': array([0.85714286, 0.85714286, 0.85714286, 0.8968254 , 0.86507937,
#         0.86507937, 0.86507937, 0.85714286, 0.85714286, 0.86507937,
#         0.85714286, 0.85714286, 0.85714286, 0.85714286, 0.85714286,
#         0.86507937, 0.85714286, 0.85714286, 0.86507937, 0.85714286,
#         0.85714286, 0.87301587, 0.85714286, 0.85714286, 0.86507937,
#         0.85714286, 0.86507937, 0.85714286, 0.85714286, 0.85714286,
#         0.85714286, 0.85714286, 0.86507937, 0.8968254 , 0.86507937,
#         0.85714286, 0.85714286, 0.86507937, 0.86507937, 0.85714286,
#         0.85714286, 0.86507937, 0.85714286, 0.85714286, 0.86507937,
#         0.83333333, 0.85714286, 0.85714286, 0.85714286, 0.86507937,
#         0.85714286, 0.84920635, 0.86507937, 0.85714286, 0.85714286,
#         0.85714286, 0.86507937, 0.86507937, 0.87301587, 0.85714286,
#         0.86507937, 0.85714286, 0.88888889, 0.86507937, 0.85714286,
#         0.86507937, 0.86507937, 0.80952381, 0.86507937, 0.86507937,
#         0.85714286, 0.86507937, 0.85714286, 0.86507937, 0.85714286,
#         0.85714286, 0.84920635, 0.86507937, 0.85714286, 0.86507937,
#         0.82539683, 0.85714286, 0.87301587, 0.8968254 , 0.85714286,
#         0.85714286, 0.86507937, 0.86507937, 0.85714286, 0.86507937,
#         0.86507937, 0.85714286, 0.85714286, 0.85714286, 0.85714286,
#         0.86507937, 0.85714286, 0.85714286, 0.85714286, 0.85714286]),
#  'split9_test_score': array([0.85714286, 0.85714286, 0.85714286, 0.84126984, 0.81746032,
#         0.80952381, 0.81746032, 0.85714286, 0.85714286, 0.81746032,
#         0.85714286, 0.85714286, 0.85714286, 0.85714286, 0.85714286,
#         0.81746032, 0.85714286, 0.85714286, 0.81746032, 0.85714286,
#         0.85714286, 0.81746032, 0.85714286, 0.85714286, 0.81746032,
#         0.85714286, 0.81746032, 0.85714286, 0.85714286, 0.85714286,
#         0.85714286, 0.85714286, 0.80952381, 0.84126984, 0.81746032,
#         0.85714286, 0.85714286, 0.81746032, 0.81746032, 0.85714286,
#         0.85714286, 0.81746032, 0.85714286, 0.85714286, 0.81746032,
#         0.81746032, 0.85714286, 0.85714286, 0.85714286, 0.80952381,
#         0.85714286, 0.85714286, 0.81746032, 0.85714286, 0.85714286,
#         0.85714286, 0.80952381, 0.80952381, 0.80952381, 0.85714286,
#         0.81746032, 0.85714286, 0.82539683, 0.81746032, 0.85714286,
#         0.81746032, 0.81746032, 0.81746032, 0.81746032, 0.81746032,
#         0.85714286, 0.81746032, 0.85714286, 0.80952381, 0.85714286,
#         0.85714286, 0.84126984, 0.81746032, 0.85714286, 0.81746032,
#         0.84126984, 0.85714286, 0.80952381, 0.84126984, 0.85714286,
#         0.85714286, 0.80952381, 0.80952381, 0.85714286, 0.81746032,
#         0.81746032, 0.85714286, 0.85714286, 0.85714286, 0.85714286,
#         0.80952381, 0.85714286, 0.85714286, 0.81746032, 0.85714286]),
#  'mean_test_score': array([0.85793651, 0.85793651, 0.85793651, 0.83888889, 0.86190476,
#         0.83174603, 0.86190476, 0.85793651, 0.85793651, 0.86111111,
#         0.85793651, 0.85793651, 0.85793651, 0.85793651, 0.85793651,
#         0.86111111, 0.85793651, 0.85793651, 0.86190476, 0.85793651,
#         0.85793651, 0.86507937, 0.85793651, 0.85793651, 0.86031746,
#         0.85793651, 0.86111111, 0.85793651, 0.85793651, 0.85793651,
#         0.85793651, 0.85793651, 0.86031746, 0.83730159, 0.86269841,
#         0.85793651, 0.85793651, 0.86269841, 0.86031746, 0.85793651,
#         0.85793651, 0.86111111, 0.85793651, 0.85793651, 0.86190476,
#         0.84047619, 0.85793651, 0.85793651, 0.85793651, 0.85793651,
#         0.85793651, 0.85      , 0.86269841, 0.85793651, 0.85793651,
#         0.85793651, 0.86031746, 0.85793651, 0.85952381, 0.85793651,
#         0.86190476, 0.85793651, 0.87222222, 0.86111111, 0.85793651,
#         0.86190476, 0.86269841, 0.84285714, 0.85873016, 0.86031746,
#         0.85793651, 0.86269841, 0.85793651, 0.85793651, 0.85793651,
#         0.85793651, 0.85      , 0.86269841, 0.85793651, 0.86190476,
#         0.84920635, 0.85793651, 0.85952381, 0.83888889, 0.85793651,
#         0.85793651, 0.86031746, 0.85793651, 0.85793651, 0.86269841,
#         0.86269841, 0.85793651, 0.85793651, 0.85793651, 0.85793651,
#         0.83174603, 0.85793651, 0.85793651, 0.83730159, 0.85793651]),
#  'std_test_score': array([0.00238095, 0.00238095, 0.00238095, 0.0253596 , 0.02332847,
#         0.01937549, 0.0201406 , 0.00238095, 0.00238095, 0.02077183,
#         0.00238095, 0.00238095, 0.00238095, 0.00238095, 0.00238095,
#         0.0213697 , 0.00238095, 0.00238095, 0.0201406 , 0.00238095,
#         0.00238095, 0.02099803, 0.00238095, 0.00238095, 0.02135496,
#         0.00238095, 0.02077183, 0.00238095, 0.00238095, 0.00238095,
#         0.00238095, 0.00238095, 0.02222222, 0.02590027, 0.01977768,
#         0.00238095, 0.00238095, 0.02274055, 0.02135496, 0.00238095,
#         0.00238095, 0.02077183, 0.00238095, 0.00238095, 0.0201406 ,
#         0.01859583, 0.00238095, 0.00238095, 0.00238095, 0.02594886,
#         0.00238095, 0.02142857, 0.01977768, 0.00238095, 0.00238095,
#         0.00238095, 0.02222222, 0.02594886, 0.03115522, 0.00238095,
#         0.02075666, 0.00238095, 0.02642988, 0.02077183, 0.00238095,
#         0.0201406 , 0.02274055, 0.02627452, 0.02529742, 0.02075666,
#         0.00238095, 0.01977768, 0.00238095, 0.02594886, 0.00238095,
#         0.00238095, 0.02257375, 0.01977768, 0.00238095, 0.0201406 ,
#         0.0154711 , 0.00238095, 0.03115522, 0.0253596 , 0.00238095,
#         0.00238095, 0.02222222, 0.02594886, 0.00238095, 0.01977768,
#         0.02274055, 0.00238095, 0.00238095, 0.00238095, 0.00238095,
#         0.01937549, 0.00238095, 0.00238095, 0.02465432, 0.00238095]),
#  'rank_test_score': array([36, 36, 36, 95, 11, 99, 11, 36, 36, 18, 36, 36, 36, 36, 36, 18, 36,
#         36, 11, 36, 36,  2, 36, 36, 23, 36, 18, 36, 36, 36, 36, 36, 23, 97,
#          3, 36, 36,  3, 23, 36, 36, 18, 36, 36, 11, 94, 36, 36, 36, 32, 36,
#         90,  3, 36, 36, 36, 23, 32, 29, 36, 11, 36,  1, 18, 36, 11,  3, 93,
#         31, 23, 36,  3, 36, 32, 36, 36, 90,  3, 36, 11, 92, 36, 29, 95, 36,
#         36, 23, 32, 36,  3,  3, 36, 36, 36, 36, 99, 36, 36, 98, 36])}

# %%
# accuracy = round((grid_search.best_score_)*100,2)
# print(bcolors.OKCYAN + 'accuracy after that train:'+ bcolors.ENDC + " ", accuracy ,"%")

# test_scores = grid_search.cv_results_['mean_test_score']
# param_values = list(grid_search.cv_results_['param_max_depth'])
# plt.figure(figsize=(12, 6))
# plt.plot(param_values, test_scores, color='red', linestyle='dashed', marker='o',
#          markerfacecolor='blue', markersize=10)
# plt.title('Accuracy Rate VS max_depth')
# plt.xlabel('max_depth')
# plt.ylabel('Accuracy')

# %% [markdown]
# # <font color = 'orange'> Random Forest </font>

# %%
rf = RandomForestClassifier(random_state = 42)

# %%
print('Parameters currently in use:\n')
pprint(rf.get_params())
# Out:
# Parameters currently in use:
#
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 42,
#  'verbose': 0,
#  'warm_start': False}

# %%
n_estimators = [int(x) for x in np.linspace(start = 10, stop = 1000, num = 15)]

max_features = ['auto', 'log2', 2, 5, 7]

max_depth = [int(x) for x in range(2, 8)]
max_depth.append(None)

min_samples_split = [2, 5, 10, 15, 20]

min_samples_leaf = [1, 3, 5, 10, 15]

max_samples = [0.1, 0.3, 0.5, 0.7]

random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'max_samples': max_samples}
pprint(random_grid)
# Out:
# {'max_depth': [2, 3, 4, 5, 6, 7, None],
#  'max_features': ['auto', 'log2', 2, 5, 7],
#  'max_samples': [0.1, 0.3, 0.5, 0.7],
#  'min_samples_leaf': [1, 3, 5, 10, 15],
#  'min_samples_split': [2, 5, 10, 15, 20],
#  'n_estimators': [10,
#                   80,
#                   151,
#                   222,
#                   292,
#                   363,
#                   434,
#                   504,
#                   575,
#                   646,
#                   717,
#                   787,
#                   858,
#                   929,
#                   1000]}

# %%
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 100, cv = 10,
                                verbose=2, random_state = 42, n_jobs = -1)

rf_random.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# RandomizedSearchCV(cv=10, estimator=RandomForestClassifier(random_state=42),
#                    n_iter=100, n_jobs=-1,
#                    param_distributions={'max_depth': [2, 3, 4, 5, 6, 7, None],
#                                         'max_features': ['auto', 'log2', 2, 5,
#                                                          7],
#                                         'max_samples': [0.1, 0.3, 0.5, 0.7],
#                                         'min_samples_leaf': [1, 3, 5, 10, 15],
#                                         'min_samples_split': [2, 5, 10, 15, 20],
#                                         'n_estimators': [10, 80, 151, 222, 292,
#                                                          363, 434, 504, 575,
#                                                          646, 717, 787, 858,
#                                                          929, 1000]},
#                    random_state=42, verbose=2)

# %% [markdown]
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#                    n_iter=100, n_jobs=-1,
#                    param_distributions={'max_depth': [2, 3, 4, 5, 6, 7, None],
#                                         'max_features': ['auto', 'log2', 2, 5,
#                                                          7],
#                                         'max_samples': [0.1, 0.3, 0.5, 0.7],
#                                         'min_samples_leaf': [1, 3, 5, 10, 15],
#                                         'min_samples_split': [2, 5, 10, 15, 20],
#                                         'n_estimators': [10, 80, 151, 222, 292,
#                                                          363, 434, 504, 575,
#                                                          646, 717, 787, 858,
#                                                          929, 1000]},
#                    random_state=42, verbose=2)

# %% [markdown]
# The most important arguments in RandomizedSearchCV are:
#
# n_iter: controls the number of different combinations to try
# cv: the number of folds to use for cross validation.
# More iterations will cover a wider search space and more cv folds reduces the chances of overfitting, but raising each will increase the run time.
# Machine learning is a field of trade-offs, and performance vs time is one of the most fundamental.
#
# We can view the best hyperparameters from fitting the random search:

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 717,
#  'min_samples_split': 15,
#  'min_samples_leaf': 1,
#  'max_samples': 0.7,
#  'max_features': 5,
#  'max_depth': None}

# %% [markdown]
#  CHECK IMPROVEMT OF RANDOM SEACH

# %%
rf.fit(X_train, y_train)
rf_y_pred = rf.predict(X_test)
rf_accuracy = metrics.accuracy_score(y_test, rf_y_pred)
print('base model accuracy = {:0.2f}%'.format(rf_accuracy*100))

best_random = rf_random.best_estimator_
random_y_pred = best_random.predict(X_test)
random_accuracy = metrics.accuracy_score(y_test, random_y_pred)
print('random model accuracy = {:0.2f}%'.format(random_accuracy*100))

print('Improvement of {:0.2f}%.'.format( 100 * (random_accuracy - rf_accuracy) / rf_accuracy))
# Out:
# base model accuracy = 87.14%
# random model accuracy = 85.24%
# Improvement of -2.19%.

# %%
param_grid = {'n_estimators': [725],
              'min_samples_split': [13,16],
              'min_samples_leaf': [1, 3],
              'max_features': ['log2', 6],
              'max_depth': [2, 4, None],
              'max_samples': [0.3, 0.8]}

grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, cv = 5, n_jobs = -1, verbose=2)

# %%
grid_search.fit(X_train, y_train)
grid_search.best_params_
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# {'max_depth': None,
#  'max_features': 6,
#  'max_samples': 0.8,
#  'min_samples_leaf': 3,
#  'min_samples_split': 13,
#  'n_estimators': 725}

# %%
grid_search.best_params_
# Out:
# {'max_depth': None,
#  'max_features': 6,
#  'max_samples': 0.8,
#  'min_samples_leaf': 3,
#  'min_samples_split': 13,
#  'n_estimators': 725}

# %% [markdown]
# {'max_depth': 4,
#  'max_features': 'log2',
#  'max_samples': 0.3,
#  'min_samples_leaf': 1,
#  'min_samples_split': 4,
#  'n_estimators': 560}

# %%
best_grid = grid_search.best_estimator_
best_grid.fit(X_train, y_train)
grid_y_pred = best_grid.predict(X_test)
grid_accuracy = metrics.accuracy_score(y_test, grid_y_pred)
print('base model accuracy = {:0.2f}%'.format(rf_accuracy*100))
print('grid model accuracy = {:0.2f}%'.format(grid_accuracy*100))
print('Improvement of {:0.2f}%.'.format( 100 * (grid_accuracy - rf_accuracy) / rf_accuracy))
# Out:
# base model accuracy = 87.14%
# grid model accuracy = 85.71%
# Improvement of -1.64%.

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### Training Curves
#
# We can perform grid search over only one parameter to observe the effects of changing that parameter on performance. We will look at training time, training set accuracy, and testing set accuracy.

# %%
tree_grid = {'n_estimators': [int(x) for x in np.linspace(1, 780, 20)]}

tree_grid_search = GridSearchCV(best_grid, param_grid=tree_grid, verbose = 2, n_jobs=-1, cv = 5,
                                scoring = 'accuracy')

# %% [markdown]
# ### Visualizing One Tree in the Forest

# %%
tree = best_grid.estimators_[20]

# %%
dot = export_graphviz(tree, filled=True, rounded=True, 
                special_characters=True,feature_names = X.columns,class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot)  
Image(graph.create_png())

# %% [markdown]
# ### ANOTHER VISUALIZE - #### Check Accuracy VS Number of trees

# %%
num_of_trees = {'n_estimators': [int(x) for x in np.linspace(1, 601, 60)]}

rf_check_grid_numTrees = GridSearchCV(estimator = rf, param_grid=num_of_trees, verbose = 2, n_jobs=-1, cv = 10,
                                scoring = 'accuracy')
rf_check_grid_numTrees.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 60 candidates, totalling 600 fits
# GridSearchCV(cv=10, estimator=RandomForestClassifier(random_state=42),
#              n_jobs=-1,
#              param_grid={'n_estimators': [1, 11, 21, 31, 41, 51, 62, 72, 82, 92,
#                                           102, 112, 123, 133, 143, 153, 163,
#                                           173, 184, 194, 204, 214, 224, 234,
#                                           245, 255, 265, 275, 285, 295, ...]},
#              scoring='accuracy', verbose=2)

# %%
test_scores = rf_check_grid_numTrees.cv_results_['mean_test_score']
param_values = list(rf_check_grid_numTrees.cv_results_['param_n_estimators'])
plt.subplots(1, figsize=(10, 6))
plt.subplot(121)
plt.plot(param_values, test_scores, 'bo-', label = 'test')
plt.xlabel('Num trees')
plt.ylabel('Accuracy')
plt.title('Accuracy VS Number of Trees' )
plt.tight_layout(pad = 2)

# %% [markdown]
# TODO לחזור להרית מפה הכל יש בעיות עם הX

# %% [markdown]
# # <font color = 'red'> SVM </font>

# %% [markdown]
# ### Find the hyperparameters;
# Hyperparameter:
# - C: Regularization, a smaller value of C creates a small-margin hyperplane and a larger value of C creates a larger-margin hyperplane.
# - Kernel: The function that used to transform the original training data into a higher dimension.

# %% [markdown]
# #### Randomized Search

# %%
svmC= svm.SVC()

print('Parameters currently in use:\n')
pprint(svmC.get_params())

# %%
SVM_random = svm.SVC(probability=True)

random_grid = {'base_estimator__C': [0.1, 1, 10],
               'base_estimator__gamma': [1, 0.1, 0.01],
               'base_estimator__kernel': ['rbf', 'poly', 'sigmoid'],
               'base_estimator__degree':[k for k in range(3,6)]
              }
n_estimators = 10

# %%
SVM_random = BaggingClassifier(base_estimator=SVC(probability=True), max_samples=1.0 / n_estimators, n_estimators=n_estimators)
SVM_random = RandomizedSearchCV(estimator = SVM_random, param_distributions = random_grid, n_iter = 81,cv = 10,
                               verbose = 2, random_state = 42, n_jobs = -1)

# %%
SVM_random.fit(X_train, y_train)
parameters = SVM_random.best_params_
# Out:
# Fitting 10 folds for each of 81 candidates, totalling 810 fits

# %%
parameters

# %%
accuracy = round(svm_grid_search.best_score_*100,2)

# %% [markdown]
# ##  - לא הצליח - לנסות עם תרגול 8 באמצע

# %%
print(type(X))

# %%
# clf_list = [dt]
# cm_dict, auc_dict = {}, {}
# # X = X.to_numpy() # run only once~~
# kf = KFold(n_splits=10, shuffle=True, random_state=42) #for cross validation
# k = 0
# for train_index, test_index in kf.split(X):
#     k+=1
#     print("------",k,"------")
#     # split to train and test
#     X_train, X_test = X[train_index], X[test_index]
#     y_train, y_test = y[train_index], y[test_index]
#     for clf in clf_list:
#         # train the model and make a prediction
#         clf.fit(X_train,y_train)
#         y_pred = clf.predict(X_test)
#         cm = metrics.confusion_matrix(y_test, y_pred)
#         y_probs = clf.predict_proba(X_test) # probability prediction
#         fpr, tpr, _ = metrics.roc_curve(y_test, y_probs[:,1])
#         auc = metrics.auc(fpr, tpr)
#         # save the results
#         cm_list = cm_dict.get(clf,[])
#         cm_list.append(cm)
#         cm_dict[clf] = cm_list
#         auc_list = auc_dict.get(clf,[])
#         auc_list.append(auc)
#         auc_dict[clf] = auc_list
#         # print the results
# #         print("Classifier: ", clf)
# #         print("Accuracy: ", metrics.accuracy_score(y_test, y_pred))

# %%
acc_dict = {}
recall_dict = {}
for clf in clf_list:
    print(clf)
    acc = [(cm[0][0]+cm[1][1])/sum(sum(cm)) for cm in cm_dict[clf]]
    acc_dict[clf] = acc 
    print("mean accuracy: ", np.mean(acc))
    recall = [(cm[1][1])/(cm[1][1]+cm[1][0]) for cm in cm_dict[clf]]
    recall_dict[clf] = recall
    print("mean recall: ", np.mean(recall))
    print("mean AUC: ", np.mean(auc_dict[clf]))

# %%
acc_dict = {}
recall_dict = {}
for clf in clf_list:
    print(clf)
    acc = [(cm[0][0]+cm[1][1])/sum(sum(cm)) for cm in cm_dict[clf]]
    acc_dict[clf] = acc 
    print("mean accuracy: ", np.mean(acc))
    recall = [(cm[1][1])/(cm[1][1]+cm[1][0]) for cm in cm_dict[clf]]
    recall_dict[clf] = recall
    print("mean recall: ", np.mean(recall))
    print("mean AUC: ", np.mean(auc_dict[clf]))

# %%
# mean_score = []
# for k in range(1,11):
#     model = DecisionTreeClassifier()
#     over = SMOTE(sampling_strategy=0.1, k_neighbors=k) # TODO here
#     under = RandomUnderSampler(sampling_strategy=0.5)
#     steps = [('over', over), ('under', under), ('model', model)]
#     pipeline = Pipeline(steps=steps)
#     cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
#     scores = cross_val_score(pipeline, X, y, scoring='roc_auc', cv=cv, n_jobs=-1)
#     score = np.mean(scores)
#     mean_score.append(score)
#     print('k=%d, Mean ROC AUC: %.3f' % (k, score))

# %%
# rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 100, cv = 5,
#                                 verbose=2, random_state = 42, n_jobs = -1)

# rf_random.fit(X_train, y_train)

# %%
# df = pd.concat([pd.DataFrame(X),pd.DataFrame(y, columns =['Response'])], axis =1)
# df.head()

# %% [markdown]
# ## before balanced

# %%
# n0 = len(df[df['Response']==0])
# n1 = len(df[df['Response']==1])
# print(n0,n1)

# %% [markdown]
# ADASYM

# %%
# oversample = ADASYN(random_state = 1)
# adasyn_X, adasyn_y = oversample.fit_resample(X, y)
# adasyn_data = pd.concat([pd.DataFrame(adasyn_X),pd.DataFrame(adasyn_y, columns =['Response'])], axis =1)
# print(adasyn_data['Response'].value_counts())
# # plot_data(adasyn_data)

# %%
# n0 = len(df[df['Response']==0])
# n1 = len(df[df['Response']==1])
# print(n0,n1)
